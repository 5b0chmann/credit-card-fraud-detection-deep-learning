# %% [markdown]
# Abschlussprojekt/
# │
# ├── data/
# │   ├── raw/
# │   │   └── creditcard.csv
# │   │
# │   └── processed/
# │
# ├── notebooks/
# │   ├── 01_EDA.ipynb
# │   ├── 02_LogisticRegression.ipynb
# │   ├── 03_RandomForest.ipynb
# │   ├── 04_DNN.ipynb
# │   └── 05_Autoencoder.ipynb
# │
# ├── src/
# │   ├── preprocessing.py
# │   ├── train_baselines.py
# │   ├── train_dnn.py
# │   ├── train_autoencoder.py
# │   ├── evaluation.py
# │   └── utils.py
# │
# ├── results/
# │   ├── metrics/
# │   ├── models/
# │   └── predictions/
# │
# ├── images/
# │   ├── eda/
# │   ├── roc_curves/
# │   └── reports/
# │
# ├── reports/
# │   ├── figures/
# │   └── final_report.md
# │
# ├── requirements.txt
# ├── README.md
# └── .gitignore

# %% [markdown]
# # Tag 1
# **Projekt aufsetzen:**
# - Ordnerstruktur prüfen
# - creditcard.csv herunterladen
# - Git-Repository initialisieren
# - requirements.txt erstellen
# - erstes Notebook 01_EDA.ipynb
# **Ergebnis:** Projekt läuft lokal sauber.

# %% [markdown]
# # Tag 2
# **EDA komplett abschließen:**
# - Datensatz laden
# - Klassenverteilung analysieren
# - Fraud-Anteil visualisieren
# - Korrelationsmatrix
# - Amount-Analyse
# - erste Erkenntnisse dokumentieren
# **Ergebnis:** Fertiges EDA-Kapitel.

# %% [markdown]
# # Tag 3
# **Logistic Regression**
# - Datenaufbereitung
# - Train/Test Split
# - Modell trainieren
# - Precision
# - Recall
# - F1
# - ROC-AUC
# **Ergebnis:** Erste Baseline.

# %% [markdown]
# # Tag 4
# **Random Forest**
# - Modell trainieren
# - Hyperparameter leicht optimieren
# - Ergebnisse speichern
# **Ergebnis:** Zweite Baseline.

# %% [markdown]
# # Tag 5
# **Deep Neural Network (Hauptteil!)**
# - TensorFlow/Keras einrichten
# - Dense Layers
# - Dropout
# - Class Weights
# - Early Stopping
# **Ergebnis:** Dein erstes echtes DL-Modell.

# %% [markdown]
# # Tag 6
# **DNN verbessern**
# - Architektur variieren
# - Learning Curves
# - ROC-Kurve
# - Confusion Matrix
# **Ergebnis:** Solide Ergebnisse für den Bericht.

# %% [markdown]
# # Tag 7
# **Autoencoder**
# - Normal Cases trainieren
# - Reconstruction Error
# - Threshold bestimmen
# - Betrug erkennen
# **Ergebnis:** Unsupervised Deep Learning.

# %% [markdown]
# # Tag 8
# **Vergleich aller Modelle**
# - Ergebnistabelle erstellen
# - ROC-Kurven vergleichen
# - Precision-Recall-Kurven
# **Ergebnis:** Forschungsfrage beantworten.

# %% [markdown]
# # Tag 9
# **README + GitHub**
# Projektbeschreibung
# - Forschungsfrage
# - Datensatz
# - Ergebnisse
# - Visualisierungen
# **Ergebnis:** Portfolio-taugliches Repository.

# %% [markdown]
# # Tag 10
# **Abschlussbericht**
# - Einleitung
# - Methodik
# - Ergebnisse
# - Diskussion
# - Fazit
# - Bezug zur Finanzverwaltung
# **Ergebnis:** Abgabefertiges Projekt.

# %% [markdown]
# # Plan für das Projekt
# - EDA
#   - lokal oder Colab
# - Logistic Regression
#   - lokal
# - Random Forest
#   - lokal
# - Deep Neural Network
#   - Colab
# - Autoencoder
#   - Colab
# - README
#   - lokal/GitHub
# - Bericht
#   - lokal
#
# So bekommst du:
# - reproduzierbaren GitHub-Code
# - keine lokalen Pfade
# - keine sensiblen Daten
# - kostenlose GPU von Colab
# - ein professionelles Portfolio-Projekt.
